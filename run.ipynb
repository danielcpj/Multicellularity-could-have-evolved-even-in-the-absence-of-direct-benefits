# %%
#This is a Julia code!
using Pkg
Pkg.activate("POProject")

using Plots
using LinearAlgebra
using DifferentialEquations
using LSODA
using Random
using StatsBase
using Distributions
using DataFrames
using CSV
using ArgParse

include("POProject/PO.jl")

#Change the parameters and random seed as desired below
parameters = (N_max = 120, gamma = 1,
 N_U = 10, N_L = 8, N_S = 20, r_o = 6.8, r_f = 1,
mixing = 0, seed = 42, LCtype = "N+1", lifeCyclesPresent = [])

sol = evolutionarySimulation(parameters, 1000);
